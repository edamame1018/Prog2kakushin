# %% [markdown]
# <a href="https://colab.research.google.com/github/edamame1018/Prog2kakushin/blob/main/work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandasを使ったプログラムの作成

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-74cfef8a-898b-412f-99d4-8552bd1599ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74cfef8a-898b-412f-99d4-8552bd1599ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 情報科学部の教員の情報を表形式のデータで表す

# %%
import pandas as pd
df = pd.read_csv('zyouhoukyouinn.csv')
df
# Out:
#         学科         専攻                   名前   役職                      メールアドレス
# 0     情報工学  コンピューティング                市原 英行   教授  ichihara@hiroshima-cu.ac.jp
# 1     情報工学  コンピューティング               井上 智生    教授     tomoo@hiroshima-cu.ac.jp
# 2     情報工学  コンピューティング                永山  忍   教授    s_naga@hiroshima-cu.ac.jp
# 3     情報工学  コンピューティング               弘中 哲夫    教授  hironaka@hiroshima-cu.ac.jp
# 4     情報工学  コンピューティング                川端 英之  准教授  kawanaka@hiroshima-cu.ac.jp
# ..     ...        ...                  ...  ...                          ...
# 92  医用情報科学     医用情報科学               福田  浩士  准教授    fukuda@hiroshima-cu.ac.jp
# 93  医用情報科学     医用情報科学               福田  浩士  准教授  fhisashi@hiroshima-cu.ac.jp
# 94  医用情報科学     医用情報科学               伊藤  孝弘   講師     ito-t@hiroshima-cu.ac.jp
# 95  医用情報科学     医用情報科学               香田  次郎   講師     kohda@hiroshima-cu.ac.jp
# 96  医用情報科学     医用情報科学  アル・ファリシィ ムハンマド・サルマン   助教  alfarisi@hiroshima-cu.ac.jp
#
# [97 rows x 5 columns]

# %% [markdown]
# 各学科の教員数を数えて、棒グラフで示すプログラム

# %%
# !pip install japanize_matplotlib
# Out:
# ...
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=cb69f9341e3ffd4d61b89346b21737825f33c359ec7cac84bafcf50b46a868fd
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize_matplotlib
# ...

# %%
import csv
from matplotlib import pyplot as plt
import japanize_matplotlib
with open('zyouhoukyouinn.csv', 'r', encoding='utf-8') as f:
  data = [x for x in csv.reader(f)]

a = 'b'
c=0
b=[]
d=0
e=[]
for i in range(len(data)-1):
  if df['学科'][i]==a:
    c+=1
  else:
    if d!=0:
      e.append(df['学科'][i-1])
      b.append(c)
    a=df['学科'][i]
    c=1
    d+=1
b.append(c)
e.append(df['学科'][i-1])
print(b)
print(e)
plt.grid(axis='y')
plt.bar(e,b,color='darkblue')
plt.title('各学科の教員数')
plt.xlabel('学科')
plt.ylabel('人数')
plt.show()
# Out:
# [27, 27, 28, 15]
# ['情報工学', '知能工学', 'システム工学', '医用情報科学']

# %% [markdown]
# 学科,専攻,名前,役職,メールアドレスのいずれかについて知りたい情報を返してくれるプログラム<br>
# (条件を絞る際、入力する項目はEnterでスキップ可)<br>
# (名前とメールアドレスは入力された文字を含んでいれば条件を満たしているものとする）

# %%
s=['学科','専攻','名前','役職','メールアドレス']
print('学科','専攻','名前','役職','メールアドレス','について調べることができます')
a=input('知りたい情報は？：')
d=[]
for x in s:
  if a!=x:
    c=input(x+'は？(Enterでスキップ可)：')
    if c!='':
      d.append(c)
    else:
      d.append(0)
  else:
    d.append(0)
df2=df
for y in range(4):
  if d[y]!=0:
    if s[y]=='学科'or'専攻'or'役職':
      df2=(df2[df2[s[y]]==d[y]])
    else:
      df2[df2[s[y]].str.contains(d[y])]
df2=df2[a]
df2
# Out:
# 学科 専攻 名前 役職 メールアドレス について調べることができます
# 知りたい情報は？：学科
# 専攻は？(Enterでスキップ可)：
# 名前は？(Enterでスキップ可)：
# 役職は？(Enterでスキップ可)：
# メールアドレスは？(Enterでスキップ可)：d
# 0       情報工学
# 1       情報工学
# 2       情報工学
# 3       情報工学
# 4       情報工学
#        ...
# 92    医用情報科学
# 93    医用情報科学
# 94    医用情報科学
# 95    医用情報科学
# 96    医用情報科学
# Name: 学科, Length: 97, dtype: object

# %% [markdown]
# 入力した文字が含まれている教員の名前を返すプログラム

# %%
a=input('一文字入力：')
b=int(len(df[df['名前'].str.contains(a)]))
print(a,'の文字が含まれている先生は'+str(b)+'人いました')
print(a,'の文字が含まれている先生のリスト')
df[df['名前'].str.contains(a)]['名前']
# Out:
# 一文字入力：カ
# カ の文字が含まれている先生は1人いました
# カ の文字が含まれている先生のリスト
# 5    ルカック・マーティン
# Name: 名前, dtype: object
